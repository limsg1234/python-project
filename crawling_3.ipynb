# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import os
path = "C:\\Users\\Elite\\Downloads\\chromedriver_win32\\chromedriver"
    
driver = webdriver.Chrome(path)
driver.implicitly_wait(3)
driver.get("https://www.iherb.com/?gclid=EAIaIQobChMIo9nej7LB3wIVzbWWCh3hLgXYEAAYASAAEgJGB_D_BwE&gclsrc=aw.ds")

#오메가3 검색
search = driver.find_element_by_name("kw")
search.send_keys("omega3")
search.submit()
#링크가져오기 위해 불러옴
html = driver.page_source
soup = BeautifulSoup(html, "lxml")
http = soup.select("div.product-inner.product-inner-wide > a.product-image")

r = []
title = []
for i in http:
    r.append(i.get('content'))

#title 가져옴
for y in http:
    title.append(y.get('title'))
print(r)
print(title)
# Out:
# ['https://www.iherb.com/pr/Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels/323', 'https://www.iherb.com/pr/California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-100-Fish-Gelatin-Softgels/62118', 'https://www.iherb.com/pr/Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-180-Softgels/8341', 'https://www.iherb.com/pr/Solgar-Omega-3-Fish-Oil-Concentrate-240-Softgels/23555', 'https://www.iherb.com/pr/Life-Extension-Omega-Foundations-Super-Omega-3-120-Softgels/67018', 'https://www.iherb.com/pr/Gummi-King-DHA-Omega-3-Gummi-for-Kids-60-Gummies/34013', 'https://www.iherb.com/pr/Now-Foods-Omega-3-180-EPA-120-DHA-500-Softgels/18104', 'https://www.iherb.com/pr/Life-Extension-Omega-Foundations-Super-Omega-3-Plus-120-Softgels/67022', 'https://www.iherb.com/pr/Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-90-Softgels/76073', 'https://www.iherb.com/pr/Now-Foods-Omega-3-Molecularly-Distilled-30-Softgels/78091', 'https://www.iherb.com/pr/California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-240-Fish-Gelatin-Softgels/86598'
# ...

# %%
# /을 기준으로 잘라서 상품명 가져옴
r[0].split('/')[4]
# Out:
# 'Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels'

# %%
# /을 기준으로 잘라서 상품코드숫자 가져옴
r[1].split('/')[5]
# Out:
# '62118'

# %%
len(r)
# Out:
# 24

# %%
# 상품코드숫자만 모음
code = []
for n in range(len(r)):
    code.append(r[n].split('/')[5])
    
print(code)
# Out:
# ['323', '62118', '8341', '23555', '67018', '34013', '18104', '67022', '76073', '78091', '86598', '30496', '67021', '26738', '723', '23362', '13149', '11541', '84979', '325', '22426', '70231', '70232', '724']

# %%
# 상품명만 모음
name = []
for nn in range(len(r)):
    name.append(r[nn].split('/')[4])
    
print(name)
len(name)
# Out:
# ['Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels', 'California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-100-Fish-Gelatin-Softgels', 'Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-180-Softgels', 'Solgar-Omega-3-Fish-Oil-Concentrate-240-Softgels', 'Life-Extension-Omega-Foundations-Super-Omega-3-120-Softgels', 'Gummi-King-DHA-Omega-3-Gummi-for-Kids-60-Gummies', 'Now-Foods-Omega-3-180-EPA-120-DHA-500-Softgels', 'Life-Extension-Omega-Foundations-Super-Omega-3-Plus-120-Softgels', 'Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-90-Softgels', 'Now-Foods-Omega-3-Molecularly-Distilled-30-Softgels', 'California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-240-Fish-Gelatin-Softgels', 'Coromega-Omega-3-Gummy-Fruits-For-Kids-60-Gummy-Fruits', 'Life-Extension-Omega-Foundations-Super-Omega-3-240-Softgels', 'Solgar-Omega-3-EPA-DHA-Triple-Strength-950-mg-100-Softgels', 'Now-Foods-Omega-3-6-9-1000-mg-250-Softgels', 'Now-Foods-Omega-3-Mini-Gels-180-Softgels', 'Solgar-Omega-3-6-9-1300-mg-120-Softgels', '21st-Century-Fish-O
# ...

# %%
# 상품명과 상품코드숫자를 합쳐서 링크를 만듬 (pr은 제품클림, r로 바꾸면 리뷰창으로 바로 들어감)
total = []
for k in range(len(code)):
    total.append('https://www.iherb.com/r/' + name[k] +"/"+ code[k])
print(total)
# Out:
# ['https://www.iherb.com/r/Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels/323', 'https://www.iherb.com/r/California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-100-Fish-Gelatin-Softgels/62118', 'https://www.iherb.com/r/Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-180-Softgels/8341', 'https://www.iherb.com/r/Solgar-Omega-3-Fish-Oil-Concentrate-240-Softgels/23555', 'https://www.iherb.com/r/Life-Extension-Omega-Foundations-Super-Omega-3-120-Softgels/67018', 'https://www.iherb.com/r/Gummi-King-DHA-Omega-3-Gummi-for-Kids-60-Gummies/34013', 'https://www.iherb.com/r/Now-Foods-Omega-3-180-EPA-120-DHA-500-Softgels/18104', 'https://www.iherb.com/r/Life-Extension-Omega-Foundations-Super-Omega-3-Plus-120-Softgels/67022', 'https://www.iherb.com/r/Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-90-Softgels/76073', 'https://www.iherb.com/r/Now-Foods-Omega-3-Molecularly-Distilled-30-Softgels/78091', 'https://www.iherb.com/r/California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-240-Fish-Gelatin-Softgels/86598', 'https://
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import os
path = "C:\\Users\\Elite\\Downloads\\chromedriver_win32\\chromedriver"
    
driver = webdriver.Chrome(path)
driver.implicitly_wait(3)


for ii in range(len(total)):
    driver.get(total[ii])
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    review = soup.select("div.review-row > div.review-core-section > div.review-text")
    print(review)
# Out:
# [<div class="review-text">Unfortunately I was not blessed with what I've seen the omega 3 melted and become the shape of the bottle very bad Storing such items should have special storing </div>, <div class="review-text">Been taking this every day for years now. Great product.</div>, <div class="review-text">Very good product!!You will be exactly happy use-G HP 8 1 8 (write together) </div>, <div class="review-text">Cheaper than retail. What a steal with the great price.</div>, <div class="review-text">it did not arrive</div>, <div class="review-text">Good value for money</div>, <div class="review-text">5+</div>, <div class="review-text">Very good </div>, <div class="review-text">Good product</div>, <div class="review-text">It seems good! Value for money too.</div>]
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import os
import math
path = "C:\\Users\\Elite\\Downloads\\chromedriver_win32\\chromedriver"
    
driver = webdriver.Chrome(path)
driver.implicitly_wait(3)



for ii in range(len(total)):
    driver.get(total[ii])
    #page = driver.find_element_by_css_selector('span.customer-rating').text
    #page = math.ceil(int(page)/10)
    for i in range(5):
        review = driver.find_elements_by_css_selector('.col-xs-24.reviews-list > div')
        print('상품명:' + name[ii])
        for div in review:
            print('리뷰', div.find_element_by_css_selector('.review-text').text)
        button = driver.find_element_by_css_selector("#root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(7) > i")
        button.click()
        time.sleep(2)
# Out:
# 상품명:Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels
# 리뷰 Unfortunately I was not blessed with what I've seen the omega 3 melted and become the shape of the bottle very bad Storing such items should have special storing
# 리뷰 Been taking this every day for years now. Great product.
# 리뷰 Very good product!!You will be exactly happy use-G HP 8 1 8 (write together)
# 리뷰 Cheaper than retail. What a steal with the great price.
# 리뷰 it did not arrive
# 리뷰 Good value for money
# 리뷰 5+
# 리뷰 Very good
# 리뷰 Good product
# 리뷰 It seems good! Value for money too.
# 상품명:Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels
# 리뷰 My absolute favorite Omega with the essential EPA and DHA. Great price! They are a bit big but you get used to it.
# 리뷰 Great
# 리뷰 Best quality product with a lowest price. I recommend it almost for everyone, good source of fatty acids.
# 리뷰 Very good
# 리뷰 Super
# 리뷰 Nice i fell it change my health
# 리뷰 Very good quality!
# 리뷰 As always, a good value product from NOW. Thanks!
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import os
import math
path = "C:\\Users\\Elite\\Downloads\\chromedriver_win32\\chromedriver"
    
driver = webdriver.Chrome(path)
driver.implicitly_wait(3)



for ii in range(len(total)):
    driver.get(total[ii])
    #page = driver.find_element_by_css_selector('span.customer-rating').text
    #page = math.ceil(int(page)/10)
    for i in range(1):
        review = driver.find_elements_by_css_selector('.col-xs-24.reviews-list > div')
        print('상품명:' + name[ii])
        
        button = driver.find_element_by_css_selector("div.paging > button.arrow-button > i.icon-recentlyviewedarrowright")
        #root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(5) > i
        ##root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(7) > i
        #root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(7) > i
        #root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(4) > i
        #root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(7) > i
        #root > div > div.container.product-reviews > div:nth-child(8) > div > button:nth-child(7)
        driver.execute_script("arguments[0].click();",button)
        time.sleep(2)
# Out:
# 상품명:Now-Foods-Omega-3-180-EPA-120-DHA-200-Softgels
# 상품명:California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-100-Fish-Gelatin-Softgels
# 상품명:Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-180-Softgels
# 상품명:Solgar-Omega-3-Fish-Oil-Concentrate-240-Softgels
# 상품명:Life-Extension-Omega-Foundations-Super-Omega-3-120-Softgels
# 상품명:Gummi-King-DHA-Omega-3-Gummi-for-Kids-60-Gummies
# 상품명:Now-Foods-Omega-3-180-EPA-120-DHA-500-Softgels
# 상품명:Life-Extension-Omega-Foundations-Super-Omega-3-Plus-120-Softgels
# 상품명:Now-Foods-Ultra-Omega-3-500-EPA-250-DHA-90-Softgels
# 상품명:Now-Foods-Omega-3-Molecularly-Distilled-30-Softgels
# 상품명:California-Gold-Nutrition-Omega-3-Premium-Fish-Oil-240-Fish-Gelatin-Softgels
# 상품명:Coromega-Omega-3-Gummy-Fruits-For-Kids-60-Gummy-Fruits
# 상품명:Life-Extension-Omega-Foundations-Super-Omega-3-240-Softgels
# 상품명:Solgar-Omega-3-EPA-DHA-Triple-Strength-950-mg-100-Softgels
# 상품명:Now-Foods-Omega-3-6-9-1000-mg-250-Softgels
# 상품명:Now-Foods-Omega-3-Mini-Gels-180-Softgels
# ...
